# %%
import os
from ast import literal_eval
import pandas as pd

from cdqa.utils.filters import filter_paragraphs
from cdqa.pipeline.cdqa_sklearn import QAPipeline
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
df = pd.read_csv('../data/bnpp_newsroom_v1.1/bnpp_newsroom-v1.1.csv', converters={'paragraphs': literal_eval})

df['paragraphs'] = df['paragraphs'].apply(filter_paragraphs)
df['content'] = df['paragraphs'].apply(lambda x: ' '.join(x))

# %%
df.head()
# Out:
#          date                                              title    category  \
# 0  14.05.2019  BNP Paribas at #VivaTech : discover the progra...  Innovation
# 1  13.05.2019  The banking jobs : Assistant Vice President – ...     Careers
# 2  13.05.2019  BNP Paribas at #VivaTech : discover the progra...  Innovation
# 3  13.05.2019  "The bank with an IT budget of more than EUR6 ...       Group
# 4  10.05.2019  BNP Paribas at #VivaTech : discover the progra...  Innovation
#
#                                                 link  \
# 0  https://group.bnpparibas/en/news/bnp-paribas-v...
# 1  https://group.bnpparibas/en/news/banking-jobs-...
# 2  https://group.bnpparibas/en/news/bnp-paribas-v...
# 3  https://group.bnpparibas/en/news/the-bank-budg...
# 4  https://group.bnpparibas/en/news/bnp-paribas-v...
#
#                                             abstract  \
# 0  From Thursday 16 to Saturday 18 May 2019, join...
# 1  Within the Group’s Corporate and Institutional...
# 2  From Thursday 16 to Saturday 18 May 2019, join...
# 3  Interview with Jean-Laurent Bonnafé, Director ...
# 4  From Thursday 16 to Saturday 18 May 2019, join...
#
#                                           paragraphs  \
# 0  [BNP Paribas at #VivaTech : discover the progr...
# 1  [Within the Group’s Corporate and Institutiona...
# 2  [BNP Paribas at #VivaTech : discover the progr...
# 3  [Interview with Jean-Laurent Bonnafé, Director...
# 4  [Viva Technology 2019: Dive into the world of ...
#
#                                              content
# 0  BNP Paribas at #VivaTech : discover the progra...
# 1  Within the Group’s Corporate and Institutional...
# 2  BNP Paribas at #VivaTech : discover the progra...
# 3  Interview with Jean-Laurent Bonnafé, Director ...
# 4  Viva Technology 2019: Dive into the world of p...

# %%
cdqa_pipeline = QAPipeline(reader='../models/bert_qa_squad_v1.1_sklearn/bert_qa_squad_v1.1_sklearn.joblib')
cdqa_pipeline.fit(X=df)
cdqa_pipeline.reader.output_dir = '../logs/'

# %%
query = 'Since when does the Excellence Program of BNP Paribas exist?'
prediction = cdqa_pipeline.predict(X=query)
# Out:
# 3it [00:00, 1416.99it/s]
# The pre-trained model you are loading is an uncased model but you have set `do_lower_case` to False. We are setting `do_lower_case=True` for you but you may want to check this behavior.
# +------+-------+--------------------------------------------------------------------+
# | rank | index |                               title                                |
# +------+-------+--------------------------------------------------------------------+
# |  1   |  853  | Green is the new blue: SRI news by BNP Paribas Investment Partners |
# |  2   |  474  |        BNP Paribas’ commitment to universities and schools         |
# |  3   |  160  |              BNP Paribas Graduate Programs in France               |
# +------+-------+--------------------------------------------------------------------+
# Time: 0.01052 seconds

# %%
# Display results
print('question: {}'.format(query))
print('answer: {}'.format(prediction))
# Out:
# question: Since when does the Excellence Program of BNP Paribas exist?
# answer: January 2016
